# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("iris.csv")

# %%
iris.shape
# Out:
# (150, 5)

# %%
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris["species"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# ## Using 2D scatter plot for  EDA

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris,hue="species",height=4)\
.map(plt.scatter,"sepal_length","sepal_width")\
.add_legend()
plt.show()

# %% [markdown]
# ### Observation
# 1. Using sepal length and sepal_width features we can distinguish Setosa from others. It is linearly separable.
# 2. Separating Versicolor from Virginica is much harder as they have considerable overlap.

# %% [markdown]
# ## Using Pair Plots for EDA

# %%
plt.close()
sns.set_style("whitegrid")
sns.pairplot(iris,hue="species",height = 4)
plt.show()

# %% [markdown]
# ## Observation
# 1. petal_length and petal_width are better for separating the species of flower.

# %% [markdown]
# ## Doing Univariate Analysis for EDA

# %%
sns.FacetGrid(iris, hue="species", height=3)\
.map(sns.histplot,"sepal_length")\
.add_legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.FacetGrid(iris, hue="species", height=3)\
.map(sns.histplot,"sepal_width")\
.add_legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.FacetGrid(iris, hue="species", height=3)\
.map(sns.histplot,"petal_length")\
.add_legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.FacetGrid(iris, hue="species", height=3)\
.map(sns.histplot,"petal_width")\
.add_legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Observation
# The order of preference of feature to classify the flowers are :
# petal_length > petal_width > sepal_length > sepal_width
